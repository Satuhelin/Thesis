# %% [markdown]
# ## Looking at the economical and banking crisis in the world and presidential travels

# %% [markdown]
# This notebook combines the data on economic crisses in the world to the traveling data of superpower leaders to see if there are patterns, especially related to China since the interviews and other data seems to show that Chinese presidents can be interestead in counties with financial troubles since they provide business opportunities.

# %%
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Using the data produced by  Harvard Business School https://www.hbs.edu/behavioral-finance-and-financial-stability/data/Pages/global.aspx
df=pd.read_csv("..data/global_crisis1.csv")

# %%
#want to see all the columns
pd.set_option('display.max_columns', None)

# %%
#showing the table and making it easier to read
df.head().T
# Out:
#                                                                                                     0  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             1800
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                          NaN
# exch_usd_alt1                                                                                     NaN
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                NaN
# Independence                                                                                        0
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                     1  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             1801
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                          NaN
# exch_usd_alt1                                                                                     NaN
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                NaN
# Independence                                                                                        0
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                     2  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             1802
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                          NaN
# exch_usd_alt1                                                                                     NaN
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                NaN
# Independence                                                                                        0
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                     3  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             1803
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                          NaN
# exch_usd_alt1                                                                                     NaN
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                NaN
# Independence                                                                                        0
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                     4
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             1804
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                          NaN
# exch_usd_alt1                                                                                     NaN
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                NaN
# Independence                                                                                        0
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0

# %%
#We only want to look at the time after 2000
df1=df[df['Year']>2000]

# %%
df1.head().T
# Out:
#                                                                                                   201  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2001
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      77.8196
# exch_usd_alt1                                                                                 77.8196
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                4.2
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                   202  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2002
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      79.7234
# exch_usd_alt1                                                                                 79.7234
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                1.4
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                   203  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2003
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      72.6128
# exch_usd_alt1                                                                                 72.6128
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                4.3
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                   204  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2004
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      72.6137
# exch_usd_alt1                                                                                 72.6137
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                4.0
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
#
#                                                                                                   205
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2005
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      73.3799
# exch_usd_alt1                                                                                 73.3799
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                1.4
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0

# %%
df1.shape
# Out:
# (1120, 27)

# %%
#using the data on bilateral meetings in analysis because multilateral meetings are not so much related to the host country, but bilateral are all about that.
traveldata=pd.read_csv("../data/bilateral_1.csv", parse_dates=["Date start", "Date end"])

# %%
traveldata['year'] = traveldata['year'].astype(int)

# %%
#merging the crisis data to traveldata
crisis = df1.merge(
    traveldata,
    left_on=['Country','Year'],
    right_on=['Location country','year'],
    how="left"
)

# %%
crisis.head().T
# Out:
#                                                                                                     0  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2001
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      77.8196
# exch_usd_alt1                                                                                 77.8196
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                4.2
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        NaN
# Unnamed: 0.1                                                                                      NaN
# pop_est                                                                                           NaN
# continent                                                                                         NaN
# name                                                                                              NaN
# iso_a3                                                                                            NaN
# gdp_md_est                                                                                        NaN
# Order                                                                                             NaN
# Country of president                                                                              NaN
# President                                                                                         NaN
# Location continent                                                                                NaN
# Location country                                                                                  NaN
# Location city                                                                                     NaN
# Date start                                                                                        NaT
# Date end                                                                                          NaT
# Subject                                                                                           NaN
# Participants                                                                                      NaN
# Source                                                                                            NaN
# Link                                                                                              NaN
# year                                                                                              NaN
#
#                                                                                                     1  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2002
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      79.7234
# exch_usd_alt1                                                                                 79.7234
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                1.4
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        NaN
# Unnamed: 0.1                                                                                      NaN
# pop_est                                                                                           NaN
# continent                                                                                         NaN
# name                                                                                              NaN
# iso_a3                                                                                            NaN
# gdp_md_est                                                                                        NaN
# Order                                                                                             NaN
# Country of president                                                                              NaN
# President                                                                                         NaN
# Location continent                                                                                NaN
# Location country                                                                                  NaN
# Location city                                                                                     NaN
# Date start                                                                                        NaT
# Date end                                                                                          NaT
# Subject                                                                                           NaN
# Participants                                                                                      NaN
# Source                                                                                            NaN
# Link                                                                                              NaN
# year                                                                                              NaN
#
#                                                                                                     2  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2003
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      72.6128
# exch_usd_alt1                                                                                 72.6128
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                4.3
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        NaN
# Unnamed: 0.1                                                                                      NaN
# pop_est                                                                                           NaN
# continent                                                                                         NaN
# name                                                                                              NaN
# iso_a3                                                                                            NaN
# gdp_md_est                                                                                        NaN
# Order                                                                                             NaN
# Country of president                                                                              NaN
# President                                                                                         NaN
# Location continent                                                                                NaN
# Location country                                                                                  NaN
# Location city                                                                                     NaN
# Date start                                                                                        NaT
# Date end                                                                                          NaT
# Subject                                                                                           NaN
# Participants                                                                                      NaN
# Source                                                                                            NaN
# Link                                                                                              NaN
# year                                                                                              NaN
#
#                                                                                                     3  \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2004
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      72.6137
# exch_usd_alt1                                                                                 72.6137
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                4.0
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        355
# Unnamed: 0.1                                                                                       82
# pop_est                                                                                   4.09694e+07
# continent                                                                                      Africa
# name                                                                                          Algeria
# iso_a3                                                                                            DZA
# gdp_md_est                                                                                     609400
# Order                                                                                             949
# Country of president                                                                            China
# President                                                                                   Hu Jintao
# Location continent                                                                                NaN
# Location country                                                                              Algeria
# Location city                                                                                 Algiers
# Date start                                                                        2004-02-03 00:00:00
# Date end                                                                          2004-02-04 00:00:00
# Subject                                             Hu Jintao attended a banquet hosted by Algeria...
# Participants                                        Hu Jintao, Li Zhaoxing, Tang Jiaxuan, Abdelazi...
# Source                                                                                            NaN
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2004
#
#                                                                                                     4
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2005
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      73.3799
# exch_usd_alt1                                                                                 73.3799
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                1.4
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        NaN
# Unnamed: 0.1                                                                                      NaN
# pop_est                                                                                           NaN
# continent                                                                                         NaN
# name                                                                                              NaN
# iso_a3                                                                                            NaN
# gdp_md_est                                                                                        NaN
# Order                                                                                             NaN
# Country of president                                                                              NaN
# President                                                                                         NaN
# Location continent                                                                                NaN
# Location country                                                                                  NaN
# Location city                                                                                     NaN
# Date start                                                                                        NaT
# Date end                                                                                          NaT
# Subject                                                                                           NaN
# Participants                                                                                      NaN
# Source                                                                                            NaN
# Link                                                                                              NaN
# year                                                                                              NaN

# %%
crisis.loc[
    lambda x: x["year"].isnull()
]["Country"].value_counts().head(10)
# Out:
# Iceland                     16
# Ecuador                     16
# United States               16
# Cote d'Ivoire               16
# Paraguay                    16
# Honduras                    16
# Central African Republic    16
# Bolivia                     16
# Dominican Republic          16
# Taiwan                      16
# Name: Country, dtype: int64

# %%
#Looking at visits by China
Chinavisits = crisis[crisis['Country of president']=='China'].copy()

# %%
Chinavisits.head().T
# Out:
#                                                                                                    3   \
# Case                                                                                                1
# CC3                                                                                               DZA
# Country                                                                                       Algeria
# Year                                                                                             2004
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                      72.6137
# exch_usd_alt1                                                                                 72.6137
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1830-1877-French coins, 1878-1964-Alegrian fra...
# exch_primary source code                                                                     AAXRXDE.
# exch_sources                                        Primary source is GFD-IFS official end-of-peri...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                 NaN
# Inflation, Annual percentages of average consum...                                                4.0
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        355
# Unnamed: 0.1                                                                                       82
# pop_est                                                                                   4.09694e+07
# continent                                                                                      Africa
# name                                                                                          Algeria
# iso_a3                                                                                            DZA
# gdp_md_est                                                                                     609400
# Order                                                                                             949
# Country of president                                                                            China
# President                                                                                   Hu Jintao
# Location continent                                                                                NaN
# Location country                                                                              Algeria
# Location city                                                                                 Algiers
# Date start                                                                        2004-02-03 00:00:00
# Date end                                                                          2004-02-04 00:00:00
# Subject                                             Hu Jintao attended a banquet hosted by Algeria...
# Participants                                        Hu Jintao, Li Zhaoxing, Tang Jiaxuan, Abdelazi...
# Source                                                                                            NaN
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2004
#
#                                                                                                    32  \
# Case                                                                                                3
# CC3                                                                                               ARG
# Country                                                                                     Argentina
# Year                                                                                             2001
# Banking Crisis                                                                                      1
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     1
# Gold Standard                                                                                       0
# exch_usd                                                                                        0.999
# exch_usd_alt1                                                                                  0.9995
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                       1
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   Peso: 18th century-present, several "types" of...
# exch_primary source code                                                                     AGXRXDE.
# exch_sources                                        Primary source is RR-GFD-IFS conversion labele...
# Domestic_Debt_In_Default                                                                            1
# Domestic_Debt_ Notes/Sources                        Domestic bond exchange (Phase 1), not targeted...
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  1
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  1
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                             1.06
# <                                                                                                   0
# Inflation, Annual percentages of average consum...                                               -1.1
# Independence                                                                                        1
# Currency Crises                                                                                     1
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        123
# Unnamed: 0.1                                                                                        9
# pop_est                                                                                   4.42933e+07
# continent                                                                               South America
# name                                                                                        Argentina
# iso_a3                                                                                            ARG
# gdp_md_est                                                                                     879400
# Order                                                                                             979
# Country of president                                                                            China
# President                                                                                 Jiang Zemin
# Location continent                                                                                NaN
# Location country                                                                            Argentina
# Location city                                                                                     NaN
# Date start                                                                        2001-04-07 00:00:00
# Date end                                                                          2001-04-09 00:00:00
# Subject                                                                        Tour of Latin Americca
# Participants                                                                                      NaN
# Source                                                         china.org.cn/english/2001/Apr/9917.htm
# Link                                                https://www.fmprc.gov.cn/web/ziliao_674904/zt_...
# year                                                                                             2001
#
#                                                                                                    35  \
# Case                                                                                                3
# CC3                                                                                               ARG
# Country                                                                                     Argentina
# Year                                                                                             2004
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                        2.969
# exch_usd_alt1                                                                                  2.9233
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                   2.969
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   Peso: 18th century-present, several "types" of...
# exch_primary source code                                                                     AGXRXDE.
# exch_sources                                        Primary source is RR-GFD-IFS conversion labele...
# Domestic_Debt_In_Default                                                                            1
# Domestic_Debt_ Notes/Sources                        Domestic bond exchange (Phase 1), not targeted...
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  1
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  1
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                             1.06
# <                                                                                                   0
# Inflation, Annual percentages of average consum...                                                4.4
# Independence                                                                                        1
# Currency Crises                                                                                     1
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        122
# Unnamed: 0.1                                                                                        9
# pop_est                                                                                   4.42933e+07
# continent                                                                               South America
# name                                                                                        Argentina
# iso_a3                                                                                            ARG
# gdp_md_est                                                                                     879400
# Order                                                                                             942
# Country of president                                                                            China
# President                                                                                   Hu Jintao
# Location continent                                                                                NaN
# Location country                                                                            Argentina
# Location city                                                                            Buenos Aires
# Date start                                                                        2004-11-16 00:00:00
# Date end                                                                          2004-11-16 00:00:00
# Subject                                             Hu Jintao held talks with Argentine President ...
# Participants                                        Hu Jintao, Bo Xilai, Li Zhaoxing, Ma Kai, Wang...
# Source                                                                                            NaN
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2004
#
#                                                                                                    46  \
# Case                                                                                                3
# CC3                                                                                               ARG
# Country                                                                                     Argentina
# Year                                                                                             2014
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                       8.5402
# exch_usd_alt1                                                                                 8.07528
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                   12.78
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   Peso: 18th century-present, several "types" of...
# exch_primary source code                                                                     AGXRXDE.
# exch_sources                                        Primary source is RR-GFD-IFS conversion labele...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  1
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  1
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                             1.06
# <                                                                                                   0
# Inflation, Annual percentages of average consum...                                                NaN
# Independence                                                                                        1
# Currency Crises                                                                                     1
# Inflation Crises                                                                                  NaN
# Unnamed: 0                                                                                        121
# Unnamed: 0.1                                                                                        9
# pop_est                                                                                   4.42933e+07
# continent                                                                               South America
# name                                                                                        Argentina
# iso_a3                                                                                            ARG
# gdp_md_est                                                                                     879400
# Order                                                                                             819
# Country of president                                                                            China
# President                                                                                  Xi Jinping
# Location continent                                                                                NaN
# Location country                                                                            Argentina
# Location city                                                                            Buenos Aires
# Date start                                                                        2014-07-18 00:00:00
# Date end                                                                          2014-07-19 00:00:00
# Subject                                             Chinese president arrives in Argentina for sta...
# Participants                                        Xi Jinping, Cristina Fernandez de Kirchner, Xi...
# Source                                              http://news.xinhuanet.com/english/china/2014-0...
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2014
#
#                                                                                                    52
# Case                                                                                                4
# CC3                                                                                               AUS
# Country                                                                                     Australia
# Year                                                                                             2003
# Banking Crisis                                                                                      0
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                  1.333333333
# exch_usd_alt1                                                                                 1.33049
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   19th century British monies, 1906-1966-Austral...
# exch_primary source code                                                                     AUXRXDE.
# exch_sources                                        Primary source is GFD-IFS official eop; alt1 s...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                   0
# Inflation, Annual percentages of average consum...                                                2.7
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        767
# Unnamed: 0.1                                                                                      137
# pop_est                                                                                   2.32324e+07
# continent                                                                                     Oceania
# name                                                                                        Australia
# iso_a3                                                                                            AUS
# gdp_md_est                                                                                  1.189e+06
# Order                                                                                             954
# Country of president                                                                            China
# President                                                                                   Hu Jintao
# Location continent                                                                                NaN
# Location country                                                                            Australia
# Location city                                                                                Canberra
# Date start                                                                        2003-10-22 00:00:00
# Date end                                                                          2003-10-24 00:00:00
# Subject                                             Hu Jintao paid a courtesy call on Australian G...
# Participants                                        Hu Jintao, Li Zhaoxing, Wang Gang, Michael Jef...
# Source                                                                                            NaN
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2003

# %%
Chinavisits.shape
# Out:
# (72, 47)

# %%
#1 means there is a crisis, 0 that there is not
Chinavisits["Banking Crisis "].value_counts()
# Out:
# 0.0    52
# 1.0    12
# Name: Banking Crisis , dtype: int64

# %%
#the relation of crisis country visits
Chinavisits["Banking Crisis "].value_counts(normalize=True)
# Out:
# 0.0    0.8125
# 1.0    0.1875
# Name: Banking Crisis , dtype: float64

# %%
#1 means there is a crisis, 0 that there is not
Chinavisits['Systemic Crisis'].value_counts()
# Out:
# 0.0    65
# 1.0     5
# Name: Systemic Crisis, dtype: int64

# %%
China_s=Chinavisits[Chinavisits['Systemic Crisis']>0]

# %%
China_s['Country'].value_counts()
#greece
# Out:
# Greece         2
# Netherlands    1
# Italy          1
# Argentina      1
# Name: Country, dtype: int64

# %%
China_b=Chinavisits[Chinavisits['Banking Crisis ']>0]

# %%
China_b['Location country'].value_counts()
# Out:
# Russia            3
# Portugal          2
# Greece            2
# Netherlands       1
# Italy             1
# Denmark           1
# Argentina         1
# United Kingdom    1
# Name: Location country, dtype: int64

# %%
#around 2008-2011 the whole of Europe had some sort of banking crisis but the situation in Portugal, Greece and Italy 
#was the gravest. Greece and Portugal are interesting because they are both visited two times and they are small, 
#not meaningful countries compared to others.
#the visits China made to Greede during the economic crisis
China_b[China_b['Location country']=='Greece'].T
# Out:
#                                                                                                   434  \
# Case                                                                                               25
# CC3                                                                                               GRC
# Country                                                                                        Greece
# Year                                                                                             2008
# Banking Crisis                                                                                      1
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     1
# Gold Standard                                                                                       0
# exch_usd                                                                                         0.72
# exch_usd_alt1                                                                                  0.7151
# exch_usd_alt2                                                                                  0.7151
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   18th century-Turkish monies, 1828-1838-phoenix...
# exch_primary source code                                                                      GREDRA$
# exch_sources                                        Primary source is US dollar level; alt1 series...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                   1
# Inflation, Annual percentages of average consum...                                                4.2
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        683
# Unnamed: 0.1                                                                                      123
# pop_est                                                                                   1.07685e+07
# continent                                                                                      Europe
# name                                                                                           Greece
# iso_a3                                                                                            GRC
# gdp_md_est                                                                                     290500
# Order                                                                                             884
# Country of president                                                                            China
# President                                                                                   Hu Jintao
# Location continent                                                                                NaN
# Location country                                                                               Greece
# Location city                                                                                  Athens
# Date start                                                                        2008-11-24 00:00:00
# Date end                                                                          2008-11-25 00:00:00
# Subject                                             Hu Jintao held talks with Greek President Karo...
# Participants                                        Hu Jintao, Chen Deming, Dai Bingguo, Ling Jihu...
# Source                                              http://news.xinhuanet.com/english/2008-11/26/c...
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2008
#
#                                                                                                   440
# Case                                                                                               25
# CC3                                                                                               GRC
# Country                                                                                        Greece
# Year                                                                                             2014
# Banking Crisis                                                                                      1
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     1
# Gold Standard                                                                                       0
# exch_usd                                                                                         0.82
# exch_usd_alt1                                                                                  0.8264
# exch_usd_alt2                                                                                  0.8264
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   18th century-Turkish monies, 1828-1838-phoenix...
# exch_primary source code                                                                      GREDRA$
# exch_sources                                        Primary source is US dollar level; alt1 series...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                   1
# Inflation, Annual percentages of average consum...                                               -1.4
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        682
# Unnamed: 0.1                                                                                      123
# pop_est                                                                                   1.07685e+07
# continent                                                                                      Europe
# name                                                                                           Greece
# iso_a3                                                                                            GRC
# gdp_md_est                                                                                     290500
# Order                                                                                             821
# Country of president                                                                            China
# President                                                                                  Xi Jinping
# Location continent                                                                                NaN
# Location country                                                                               Greece
# Location city                                                                                  Rhodes
# Date start                                                                        2014-07-13 00:00:00
# Date end                                                                          2014-07-13 00:00:00
# Subject                                             #China, #Greece agree to enhance comprehensive...
# Participants                                        Xi Jinping, Antonis Samaras, Xi Jinping, Karol...
# Source                                              http://news.xinhuanet.com/english/china/2014-0...
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2014

# %%
traveldata[traveldata['Location country']=='Greece']\
    .groupby(["Country of president", "year"])["Location country"]\
    .size()
# Out:
# Country of president  year
# China                 2008    1
#                       2014    1
#                       2019    1
# Russia                2001    1
#                       2006    1
#                       2007    1
#                       2016    1
# USA                   2016    1
# Name: Location country, dtype: int64

# %% [markdown]
# There are two conclusions to make 1) Chinese presidents didn't travel to Greece before its economical crisis. 2) Chinese presidents were the only superpower presidents having a bilateral meetings with Greece during the crisis data defines being 2008-2014.

# %%
China_b[China_b['Location country']=='Portugal'].T
# Out:
#                                                                                                   893  \
# Case                                                                                               52
# CC3                                                                                               PRT
# Country                                                                                      Portugal
# Year                                                                                             2010
# Banking Crisis                                                                                      1
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                         0.75
# exch_usd_alt1                                                                                0.647179
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1722-1911-milreis, 1911-1998 escudo, 1999-pres...
# exch_primary source code                                                                          NaN
# exch_sources                                        Primary source is PTE adjusted; alt1 series is...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                   0
# Inflation, Annual percentages of average consum...                                                1.4
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        738
# Unnamed: 0.1                                                                                      131
# pop_est                                                                                   1.08395e+07
# continent                                                                                      Europe
# name                                                                                         Portugal
# iso_a3                                                                                            PRT
# gdp_md_est                                                                                     297100
# Order                                                                                             861
# Country of president                                                                            China
# President                                                                                   Hu Jintao
# Location continent                                                                                NaN
# Location country                                                                             Portugal
# Location city                                                                                  Lisbon
# Date start                                                                        2010-11-06 00:00:00
# Date end                                                                          2010-11-08 00:00:00
# Subject                                             Chinese president arrives in Lisbon for state ...
# Participants                                        Hu Jintao, Anibal Cavaco Silva, Hu Jintao, Jos...
# Source                                              http://news.xinhuanet.com/english2010/china/20...
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2010
#
#                                                                                                   897
# Case                                                                                               52
# CC3                                                                                               PRT
# Country                                                                                      Portugal
# Year                                                                                             2014
# Banking Crisis                                                                                      1
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     0
# Gold Standard                                                                                       0
# exch_usd                                                                                         0.82
# exch_usd_alt1                                                                                 0.60773
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1722-1911-milreis, 1911-1998 escudo, 1999-pres...
# exch_primary source code                                                                          NaN
# exch_sources                                        Primary source is PTE adjusted; alt1 series is...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  1
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                   1
# Inflation, Annual percentages of average consum...                                               -0.2
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        737
# Unnamed: 0.1                                                                                      131
# pop_est                                                                                   1.08395e+07
# continent                                                                                      Europe
# name                                                                                         Portugal
# iso_a3                                                                                            PRT
# gdp_md_est                                                                                     297100
# Order                                                                                             816
# Country of president                                                                            China
# President                                                                                  Xi Jinping
# Location continent                                                                                NaN
# Location country                                                                             Portugal
# Location city                                                                         Terceira Island
# Date start                                                                        2014-07-24 00:00:00
# Date end                                                                          2014-07-24 00:00:00
# Subject                                             China stands ready to deepen cooperation with ...
# Participants                                                                 Xi Jinping, Paulo Portas
# Source                                              http://news.xinhuanet.com/english/china/2014-0...
# Link                                                http://www.chinavitae.com//vip/index.php?mode=...
# year                                                                                             2014

# %% [markdown]
# Meeting descriptions with Portugal and Greece include lot of "enchanded co-operation and strategic partnership that is not self-evident with a superpower like China and minor European countries.

# %% [markdown]
# ## Comparison to the US

# %%
USAvisits=crisis[crisis['Country of president']=='USA'].copy()

# %%
#as many countries with banking crisis as China but the relation of crisis country visits is lower 
USAvisits['Banking Crisis '].value_counts()
# Out:
# 0.0    93
# 1.0    12
# Name: Banking Crisis , dtype: int64

# %%
USAvisits['Banking Crisis '].value_counts(normalize=True)
# Out:
# 0.0    0.885714
# 1.0    0.114286
# Name: Banking Crisis , dtype: float64

# %%
USA_b=USAvisits[USAvisits['Banking Crisis ']>0].copy()

# %%
#Even there are as many visits as China has, there is not a country that US would visit in any case, they are European NATO allies.
USA_b['Country'].value_counts()
# Out:
# France            3
# United Kingdom    2
# Germany           2
# Italy             2
# Russia            2
# Denmark           1
# Name: Country, dtype: int64

# %% [markdown]
# ## Comparison to Russia

# %%
Rusvisits=crisis[crisis['Country of president']=='Russia'].copy()

# %%
#more visits to crisis countries than other two, also the relation is higher
Rusvisits['Banking Crisis '].value_counts()
# Out:
# 0.0    102
# 1.0     28
# Name: Banking Crisis , dtype: int64

# %%
Rusvisits['Banking Crisis '].value_counts(normalize=True)
# Out:
# 0.0    0.784615
# 1.0    0.215385
# Name: Banking Crisis , dtype: float64

# %%
Rus_b=Rusvisits[Rusvisits['Banking Crisis ']>0]

# %%
Rus_b['Country'].value_counts()
# Out:
# Italy             7
# France            5
# Germany           5
# United Kingdom    4
# Denmark           2
# Nigeria           1
# Spain             1
# Belgium           1
# Sweden            1
# Netherlands       1
# Name: Country, dtype: int64

# %% [markdown]
# These are rich European countries that Russia would visit in any case. Most of the countries are places Russia would visit in any case. Only Nigeria is a clear excepton but it is possible that Russia is somewhat interested in countries with economic crisis even the correlation is not clear in here.

# %%
Rus_b[Rus_b['Location country']=='Nigeria'].T
# Out:
#                                                                                                   780
# Case                                                                                               45
# CC3                                                                                               NGA
# Country                                                                                       Nigeria
# Year                                                                                             2009
# Banking Crisis                                                                                      1
# Banking_Crisis_Notes                                                                              NaN
# Systemic Crisis                                                                                     1
# Gold Standard                                                                                     NaN
# exch_usd                                                                                      149.581
# exch_usd_alt1                                                                                 149.581
# exch_usd_alt2                                                                                     NaN
# exch_usd_alt3                                                                                     NaN
# conversion_notes                                    Series already adjusted for 100-to-1 conversio...
# national currency                                   1907-1913 UK pound, 1913-1959 West Africa poun...
# exch_primary source code                                                                          NaN
# exch_sources                                        Primary source is US dollar level; alt1 series...
# Domestic_Debt_In_Default                                                                            0
# Domestic_Debt_ Notes/Sources                                                                      NaN
# SOVEREIGN EXTERNAL DEBT 1: DEFAULT and RESTRUCT...                                                  0
# SOVEREIGN EXTERNAL DEBT 2: DEFAULT and RESTRUCT...                                                  0
# Defaults_External_Notes                                                                           NaN
# GDP_Weighted_default                                                                                0
# <                                                                                                   1
# Inflation, Annual percentages of average consum...                                               12.5
# Independence                                                                                        1
# Currency Crises                                                                                     0
# Inflation Crises                                                                                    0
# Unnamed: 0                                                                                        314
# Unnamed: 0.1                                                                                       56
# pop_est                                                                                   1.90632e+08
# continent                                                                                      Africa
# name                                                                                          Nigeria
# iso_a3                                                                                            NGA
# gdp_md_est                                                                                  1.089e+06
# Order                                                                                             529
# Country of president                                                                           Russia
# President                                                                             Dmitry Medvedev
# Location continent                                                                                NaN
# Location country                                                                              Nigeria
# Location city                                                                                     NaN
# Date start                                                                        2009-06-24 00:00:00
# Date end                                                                                          NaT
# Subject                                                    Russian-Nigerian talks took place in Abuja
# Participants                                                                                      NaN
# Source                                                                                            NaN
# Link                                                 http://en.kremlin.ru/events/president/trips/4892
# year                                                                                             2009

# %%
Rusvisits['Systemic Crisis'].value_counts()
# Out:
# 0.0    120
# 1.0     20
# Name: Systemic Crisis, dtype: int64

# %%
Russia_S=Rusvisits[Rusvisits['Systemic Crisis']>0].copy()

# %%
Russia_S['Country'].value_counts()
# Out:
# Italy          7
# Germany        7
# South Korea    1
# Belgium        1
# Nigeria        1
# Greece         1
# Netherlands    1
# Hungary        1
# Name: Country, dtype: int64

# %% [markdown]
# With Russia, Nigeria shows up in both catagories, but it is only one visit.
